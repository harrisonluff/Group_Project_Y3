# %%
import sys
from pathlib import Path

p = Path.cwd().resolve()
repo_root = next((parent for parent in [p] + list(p.parents) if (parent / ".git").exists()), None)
if repo_root is None:
    raise RuntimeError("Repo root not found. Open the repo folder in VS Code.")

sys.path.insert(0, str(repo_root))
print("Repo root:", repo_root)

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# Out:
# Repo root: C:\Users\harri\OneDrive - Imperial College London\Year 3 Group Project\Group_Project_Y3

# %%
county_codes = pd.read_csv(repo_root / "cleaned/00_codes/county_codes.csv")
county_codes
# Out:
#      county_code      county_kts            county_name
# 0            201  10030210101000   Powiat bolesławiecki
# 1            202  10030210302000  Powiat dzierżoniowski
# 2            203  10030210203000       Powiat głogowski
# 3            204  10030210204000        Powiat górowski
# 4            205  10030210105000        Powiat jaworski
# ..           ...             ...                    ...
# 375         3217  10023216417000         Powiat wałecki
# 376         3218  10023216418000         Powiat łobeski
# 377         3261  10023216361000     Powiat m. Koszalin
# 378         3262  10023216562000     Powiat m. Szczecin
# 379         3263  10023216663000  Powiat m. Świnoujście
#
# [380 rows x 3 columns]

# %% [markdown]
# **SECTION 1 - UNEMPLOYMENT BY POWIAT**
#
# We will take both ru measures and sum by powait (to check sum consistent). then taking one we will merge with powiat measures of economically active -> unemployment rate by powiat.

# %%
p1946 = pd.read_csv(repo_root / "cleaned/03_01_outcome_data/ru_sex_age_p1946.csv", index_col=0)
p1947 = pd.read_csv(repo_root / "cleaned/03_01_outcome_data/ru_sex_ed_p1947.csv", index_col=0)

# Create county_code column for each
for df in [p1946, p1947]:
    df["county_code"] = df["code"].apply(lambda x: int(str(x)[:-3]))

# Now take only sex total and age/education total
p1946 = p1946[
    (p1946["age"]=="total") & (p1946["sex"]=="total")
]

p1947 = p1947[
    (p1947["education"]=="total") & (p1947["sex"]=="total")
]

ru_series_p1946 = p1946.groupby(["county_code", "year"])["count"].sum()
ru_series_p1947 = p1947.groupby(["county_code", "year"])["count"].sum()

(ru_series_p1946 == ru_series_p1947).sum()
# Out:
# np.int64(9880)

# %% [markdown]
# Given they are the same we will use the first

# %%
ru_series_p1946 = ru_series_p1946.reset_index()
ru_series_p1946 = ru_series_p1946.rename(columns={"count": "ru"})
ru_series_p1946
# Out:
#       county_code  year      ru
# 0             201  2000  8886.0
# 1             201  2001  9218.0
# 2             201  2002  8574.0
# 3             201  2003  8803.0
# 4             201  2004  7966.0
# ...           ...   ...     ...
# 9875         3263  2021   559.0
# 9876         3263  2022   521.0
# 9877         3263  2023   545.0
# 9878         3263  2024   585.0
# 9879         3263  2025   686.0
#
# [9880 rows x 3 columns]

# %% [markdown]
# Gather required columns from poplation powiat table

# %%
ptot = pd.read_csv(repo_root / "cleaned/03_01_outcome_tables/population_powiat.csv", index_col=0)

ptot_cols = [
    "county_code", "year",
    "county_kts", "county_name",
    "tp1_nc_pop", "tp2_yr_pop", "tp3b_nc_active", "tp4b_active", "tp5b_active", "tp6b_active"
]

ptot = ptot[ptot_cols]

# %% [markdown]
# Now merge the tables:

# %%
ru_series_p1946.set_index(["county_code", "year"], inplace=True)
ptot.set_index(["county_code", "year"], inplace=True)

ru_powiat = ru_series_p1946.join(ptot, how="left").reset_index()

# Save
ru_powiat.to_csv(repo_root / "cleaned/03_01_outcome_tables/unemploy_table.csv")

ru_powiat
# Out:
#       county_code  year      ru    county_kts            county_name  \
# 0             201  2000  8886.0  1.003021e+13   Powiat bolesławiecki
# 1             201  2001  9218.0  1.003021e+13   Powiat bolesławiecki
# 2             201  2002  8574.0  1.003021e+13   Powiat bolesławiecki
# 3             201  2003  8803.0  1.003021e+13   Powiat bolesławiecki
# 4             201  2004  7966.0  1.003021e+13   Powiat bolesławiecki
# ...           ...   ...     ...           ...                    ...
# 9875         3263  2021   559.0  1.002322e+13  Powiat m. Świnoujście
# 9876         3263  2022   521.0  1.002322e+13  Powiat m. Świnoujście
# 9877         3263  2023   545.0  1.002322e+13  Powiat m. Świnoujście
# 9878         3263  2024   585.0  1.002322e+13  Powiat m. Świnoujście
# 9879         3263  2025   686.0           NaN                    NaN
#
#       tp1_nc_pop  tp2_yr_pop  tp3b_nc_active  tp4b_active  tp5b_active  \
# 0        76739.0     64323.0         40280.0      37565.0          NaN
# 1        76739.0     64858.0         40280.0      37877.0          NaN
# 2        76739.0     71744.0         40280.0      41898.0          NaN
# 3        76739.0     72499.0         40280.0      42339.0          NaN
# 4        76739.0     73078.0         40280.0      42678.0          NaN
# ...          ...         ...             ...          ...          ...
# 9875     35988.0     34960.0         17737.0      19752.0      19578.0
# 9876     35988.0     34619.0         17737.0      19560.0      19664.0
# 9877     35988.0     34317.0         17737.0      19389.0      19664.0
# 9878     35988.0     34148.0         17737.0      19294.0      19499.0
# 9879         NaN         NaN             NaN          NaN          NaN
#
#       tp6b_active
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 9875      19752.0
# 9876      19839.0
# 9877      19839.0
# 9878      19673.0
# 9879          NaN
#
# [9880 rows x 11 columns]

# %%
ru_series_p1946
# Out:
#                       ru
# county_code year
# 201         2000  8886.0
#             2001  9218.0
#             2002  8574.0
#             2003  8803.0
#             2004  7966.0
# ...                  ...
# 3263        2021   559.0
#             2022   521.0
#             2023   545.0
#             2024   585.0
#             2025   686.0
#
# [9880 rows x 1 columns]

# %% [markdown]
# **SECTION 2 - UNEMPLOYMENT POWIAT SEX AGE:**

# %%
p1946 = pd.read_csv(repo_root / "cleaned/03_01_outcome_data/ru_sex_age_p1946.csv", index_col=0)

# create county code
p1946["county_code"] = p1946["code"].apply(lambda x: int(str(x)[:-3]))

# drop total sex and irrelevant ages
p1946 = p1946[~(p1946["sex"]=="total")].copy()
p1946 = p1946[~(p1946["age"].isin(["total", "25 and more"]))].copy()

# rename count column
p1946.rename(columns={"count": "ru", "age": "age_group"}, inplace=True)

# set up ready for join
ru_sa_table = p1946.set_index(["county_code", "year", "sex", "age_group"])[["ru"]]
ru_sa_table
# Out:
#                                              ru
# county_code year sex     age_group
# 201         2000 males   under 25 years  1154.0
# 202         2000 males   under 25 years  1265.0
# 203         2000 males   under 25 years  1131.0
# 204         2000 males   under 25 years   562.0
# 205         2000 males   under 25 years   708.0
# ...                                         ...
# 3217        2025 females 55 and more       79.0
# 3218        2025 females 55 and more       75.0
# 3261        2025 females 55 and more      146.0
# 3262        2025 females 55 and more      343.0
# 3263        2025 females 55 and more       44.0
#
# [98800 rows x 1 columns]

# %%
psa = pd.read_csv(repo_root / "cleaned/03_01_outcome_tables/population_powiat_sex_age.csv", index_col=0)

psa
# Out:
#         county_code  year      sex       age_group  psa1_nc_pop  psa2_yr_pop  \
# 0               201  1995  females  under 25 years         4001       6879.0
# 1               201  1995  females           25-34         5751       5740.0
# 2               201  1995  females           35-44         7153       7825.0
# 3               201  1995  females           45-54         5805       5051.0
# 4               201  1995  females     55 and more        16198       6775.0
# ...             ...   ...      ...             ...          ...          ...
# 113335         3263  2024    males  under 25 years         1489       1556.0
# 113336         3263  2024    males           25-34         2464       1898.0
# 113337         3263  2024    males           35-44         3441       3070.0
# 113338         3263  2024    males           45-54         2795       3132.0
# 113339         3263  2024    males     55 and more         6582       6189.0
#
#         psa3a_employed  psa3b_active  psa4a_employed  psa4b_active
# 0               2430.0        2522.0             NaN           NaN
# 1               4129.0        4285.0             NaN           NaN
# 2               5426.0        5630.0             NaN           NaN
# 3               3599.0        3735.0             NaN           NaN
# 4               1491.0        1547.0             NaN           NaN
# ...                ...           ...             ...           ...
# 113335           483.0         511.0           456.0         478.0
# 113336          1395.0        1477.0          1733.0        1646.0
# 113337          2051.0        2171.0          2803.0        2662.0
# 113338          2017.0        2135.0          2860.0        2715.0
# 113339          2345.0        2482.0          2717.0        2742.0
#
# [113340 rows x 10 columns]

# %%
ru_sa_table = ru_sa_table.join(
    psa.set_index(["county_code", "year", "sex", "age_group"]), how="outer"
).reset_index()
ru_sa_table
# Out:
#         county_code  year      sex       age_group     ru  psa1_nc_pop  \
# 0               201  1995  females           25-34    NaN       5751.0
# 1               201  1995  females           35-44    NaN       7153.0
# 2               201  1995  females           45-54    NaN       5805.0
# 3               201  1995  females     55 and more    NaN      16198.0
# 4               201  1995  females  under 25 years    NaN       4001.0
# ...             ...   ...      ...             ...    ...          ...
# 117395         3263  2025    males           25-34   52.0          NaN
# 117396         3263  2025    males           35-44   92.0          NaN
# 117397         3263  2025    males           45-54  118.0          NaN
# 117398         3263  2025    males     55 and more  118.0          NaN
# 117399         3263  2025    males  under 25 years   18.0          NaN
#
#         psa2_yr_pop  psa3a_employed  psa3b_active  psa4a_employed  \
# 0            5740.0          4129.0        4285.0             NaN
# 1            7825.0          5426.0        5630.0             NaN
# 2            5051.0          3599.0        3735.0             NaN
# 3            6775.0          1491.0        1547.0             NaN
# 4            6879.0          2430.0        2522.0             NaN
# ...             ...             ...           ...             ...
# 117395          NaN             NaN           NaN             NaN
# 117396          NaN             NaN           NaN             NaN
# 117397          NaN             NaN           NaN             NaN
# 117398          NaN             NaN           NaN             NaN
# 117399          NaN             NaN           NaN             NaN
#
#         psa4b_active
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 117395           NaN
# 117396           NaN
# 117397           NaN
# 117398           NaN
# 117399           NaN
#
# [117400 rows x 11 columns]

# %%
ru_sa_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117400 entries, 0 to 117399
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   county_code     117400 non-null  int64
#  1   year            117400 non-null  int64
#  2   sex             117400 non-null  object
#  3   age_group       117400 non-null  object
#  4   ru              98510 non-null   float64
#  5   psa1_nc_pop     113340 non-null  float64
#  6   psa2_yr_pop     113340 non-null  float64
#  7   psa3a_employed  113340 non-null  float64
#  8   psa3b_active    113340 non-null  float64
#  9   psa4a_employed  56970 non-null   float64
#  10  psa4b_active    22800 non-null   float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 9.9+ MB

# %% [markdown]
# Can extend psa1 - the nc 2021 - to 2025 ru measure

# %%
# mask = ru_sa_table["year"] == 2025

# ru_sa_table.loc[mask, "psa1_nc_pop"] = (
#     ru_sa_table.groupby(["county_code", "sex", "age_group"])["psa1_nc_pop"]
#       .transform("first")[mask]
# )

ru_sa_table["psa1_nc_pop"] = ru_sa_table["psa1_nc_pop"].fillna(
    ru_sa_table.groupby(["county_code", "sex", "age_group"])["psa1_nc_pop"].transform("first")
)

ru_sa_table
# Out:
#         county_code  year      sex       age_group     ru  psa1_nc_pop  \
# 0               201  1995  females           25-34    NaN       5751.0
# 1               201  1995  females           35-44    NaN       7153.0
# 2               201  1995  females           45-54    NaN       5805.0
# 3               201  1995  females     55 and more    NaN      16198.0
# 4               201  1995  females  under 25 years    NaN       4001.0
# ...             ...   ...      ...             ...    ...          ...
# 117395         3263  2025    males           25-34   52.0       2464.0
# 117396         3263  2025    males           35-44   92.0       3441.0
# 117397         3263  2025    males           45-54  118.0       2795.0
# 117398         3263  2025    males     55 and more  118.0       6582.0
# 117399         3263  2025    males  under 25 years   18.0       1489.0
#
#         psa2_yr_pop  psa3a_employed  psa3b_active  psa4a_employed  \
# 0            5740.0          4129.0        4285.0             NaN
# 1            7825.0          5426.0        5630.0             NaN
# 2            5051.0          3599.0        3735.0             NaN
# 3            6775.0          1491.0        1547.0             NaN
# 4            6879.0          2430.0        2522.0             NaN
# ...             ...             ...           ...             ...
# 117395          NaN             NaN           NaN             NaN
# 117396          NaN             NaN           NaN             NaN
# 117397          NaN             NaN           NaN             NaN
# 117398          NaN             NaN           NaN             NaN
# 117399          NaN             NaN           NaN             NaN
#
#         psa4b_active
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 117395           NaN
# 117396           NaN
# 117397           NaN
# 117398           NaN
# 117399           NaN
#
# [117400 rows x 11 columns]

# %%
check_table = ru_sa_table.groupby(["county_code", "sex", "age_group"])["psa1_nc_pop"].agg(["mean", "std"])
check_table[check_table["std"]>0]
# Out:
# Empty DataFrame
# Columns: [mean, std]
# Index: []

# %%
ru_sa_table[ru_sa_table["county_code"]==3263].head(10)
ru_sa_table[ru_sa_table["county_code"]==3263].tail(10)
# Out:
#         county_code  year      sex       age_group     ru  psa1_nc_pop  \
# 117390         3263  2025  females           25-34   59.0       2401.0
# 117391         3263  2025  females           35-44   87.0       3285.0
# 117392         3263  2025  females           45-54   79.0       2800.0
# 117393         3263  2025  females     55 and more   44.0       8534.0
# 117394         3263  2025  females  under 25 years   19.0       1484.0
# 117395         3263  2025    males           25-34   52.0       2464.0
# 117396         3263  2025    males           35-44   92.0       3441.0
# 117397         3263  2025    males           45-54  118.0       2795.0
# 117398         3263  2025    males     55 and more  118.0       6582.0
# 117399         3263  2025    males  under 25 years   18.0       1489.0
#
#         psa2_yr_pop  psa3a_employed  psa3b_active  psa4a_employed  \
# 117390          NaN             NaN           NaN             NaN
# 117391          NaN             NaN           NaN             NaN
# 117392          NaN             NaN           NaN             NaN
# 117393          NaN             NaN           NaN             NaN
# 117394          NaN             NaN           NaN             NaN
# 117395          NaN             NaN           NaN             NaN
# 117396          NaN             NaN           NaN             NaN
# 117397          NaN             NaN           NaN             NaN
# 117398          NaN             NaN           NaN             NaN
# 117399          NaN             NaN           NaN             NaN
#
#         psa4b_active
# 117390           NaN
# 117391           NaN
# 117392           NaN
# 117393           NaN
# 117394           NaN
# 117395           NaN
# 117396           NaN
# 117397           NaN
# 117398           NaN
# 117399           NaN

# %%
ru_sa_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117400 entries, 0 to 117399
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   county_code     117400 non-null  int64
#  1   year            117400 non-null  int64
#  2   sex             117400 non-null  object
#  3   age_group       117400 non-null  object
#  4   ru              98510 non-null   float64
#  5   psa1_nc_pop     117400 non-null  float64
#  6   psa2_yr_pop     113340 non-null  float64
#  7   psa3a_employed  113340 non-null  float64
#  8   psa3b_active    113340 non-null  float64
#  9   psa4a_employed  56970 non-null   float64
#  10  psa4b_active    22800 non-null   float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 9.9+ MB

# %%
ru_sa_table[ru_sa_table["psa1_nc_pop"].isna()]
# Out:
# Empty DataFrame
# Columns: [county_code, year, sex, age_group, ru, psa1_nc_pop, psa2_yr_pop, psa3a_employed, psa3b_active, psa4a_employed, psa4b_active]
# Index: []

# %%
ru_sa_table[ru_sa_table["county_code"]==3218].head(25)
# Out:
#         county_code  year      sex       age_group     ru  psa1_nc_pop  \
# 116210         3218  2000  females           25-34    NaN       2015.0
# 116211         3218  2000  females           35-44    NaN       2530.0
# 116212         3218  2000  females           45-54    NaN       2073.0
# 116213         3218  2000  females     55 and more    NaN       6526.0
# 116214         3218  2000  females  under 25 years    NaN       1641.0
# 116215         3218  2000    males           25-34    NaN       2250.0
# 116216         3218  2000    males           35-44    NaN       2835.0
# 116217         3218  2000    males           45-54    NaN       2288.0
# 116218         3218  2000    males     55 and more    NaN       5319.0
# 116219         3218  2000    males  under 25 years    NaN       1798.0
# 116220         3218  2001  females           25-34    NaN       2015.0
# 116221         3218  2001  females           35-44    NaN       2530.0
# 116222         3218  2001  females           45-54    NaN       2073.0
# 116223         3218  2001  females     55 and more    NaN       6526.0
# 116224         3218  2001  females  under 25 years    NaN       1641.0
# 116225         3218  2001    males           25-34    NaN       2250.0
# 116226         3218  2001    males           35-44    NaN       2835.0
# 116227         3218  2001    males           45-54    NaN       2288.0
# 116228         3218  2001    males     55 and more    NaN       5319.0
# 116229         3218  2001    males  under 25 years    NaN       1798.0
# 116230         3218  2002  females           25-34  884.0       2015.0
# 116231         3218  2002  females           35-44  694.0       2530.0
# 116232         3218  2002  females           45-54  561.0       2073.0
# 116233         3218  2002  females     55 and more   33.0       6526.0
# 116234         3218  2002  females  under 25 years  754.0       1641.0
#
#         psa2_yr_pop  psa3a_employed  psa3b_active  psa4a_employed  \
# 116210          NaN             NaN           NaN             NaN
# 116211          NaN             NaN           NaN             NaN
# 116212          NaN             NaN           NaN             NaN
# 116213          NaN             NaN           NaN             NaN
# 116214          NaN             NaN           NaN             NaN
# 116215          NaN             NaN           NaN             NaN
# 116216          NaN             NaN           NaN             NaN
# 116217          NaN             NaN           NaN             NaN
# 116218          NaN             NaN           NaN             NaN
# 116219          NaN             NaN           NaN             NaN
# 116220          NaN             NaN           NaN             NaN
# 116221          NaN             NaN           NaN             NaN
# 116222          NaN             NaN           NaN             NaN
# 116223          NaN             NaN           NaN             NaN
# 116224          NaN             NaN           NaN             NaN
# 116225          NaN             NaN           NaN             NaN
# 116226          NaN             NaN           NaN             NaN
# 116227          NaN             NaN           NaN             NaN
# 116228          NaN             NaN           NaN             NaN
# 116229          NaN             NaN           NaN             NaN
# 116230       2336.0          1438.0        1543.0             NaN
# 116231       2611.0          1660.0        1781.0             NaN
# 116232       3010.0          1981.0        2125.0             NaN
# 116233       4524.0           906.0         972.0             NaN
# 116234       3151.0          1097.0        1177.0             NaN
#
#         psa4b_active
# 116210           NaN
# 116211           NaN
# 116212           NaN
# 116213           NaN
# 116214           NaN
# 116215           NaN
# 116216           NaN
# 116217           NaN
# 116218           NaN
# 116219           NaN
# 116220           NaN
# 116221           NaN
# 116222           NaN
# 116223           NaN
# 116224           NaN
# 116225           NaN
# 116226           NaN
# 116227           NaN
# 116228           NaN
# 116229           NaN
# 116230           NaN
# 116231           NaN
# 116232           NaN
# 116233           NaN
# 116234           NaN

# %%
# Save
ru_sa_table.to_csv(repo_root / "cleaned/03_01_outcome_tables/unemploy_sex_age_table.csv")

ru_sa_table
# Out:
#         county_code  year      sex       age_group     ru  psa1_nc_pop  \
# 0               201  1995  females           25-34    NaN       5751.0
# 1               201  1995  females           35-44    NaN       7153.0
# 2               201  1995  females           45-54    NaN       5805.0
# 3               201  1995  females     55 and more    NaN      16198.0
# 4               201  1995  females  under 25 years    NaN       4001.0
# ...             ...   ...      ...             ...    ...          ...
# 117395         3263  2025    males           25-34   52.0       2464.0
# 117396         3263  2025    males           35-44   92.0       3441.0
# 117397         3263  2025    males           45-54  118.0       2795.0
# 117398         3263  2025    males     55 and more  118.0       6582.0
# 117399         3263  2025    males  under 25 years   18.0       1489.0
#
#         psa2_yr_pop  psa3a_employed  psa3b_active  psa4a_employed  \
# 0            5740.0          4129.0        4285.0             NaN
# 1            7825.0          5426.0        5630.0             NaN
# 2            5051.0          3599.0        3735.0             NaN
# 3            6775.0          1491.0        1547.0             NaN
# 4            6879.0          2430.0        2522.0             NaN
# ...             ...             ...           ...             ...
# 117395          NaN             NaN           NaN             NaN
# 117396          NaN             NaN           NaN             NaN
# 117397          NaN             NaN           NaN             NaN
# 117398          NaN             NaN           NaN             NaN
# 117399          NaN             NaN           NaN             NaN
#
#         psa4b_active
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 117395           NaN
# 117396           NaN
# 117397           NaN
# 117398           NaN
# 117399           NaN
#
# [117400 rows x 11 columns]

# %% [markdown]
# ****SECTION 3 - UNEMPLOYMENT BY SEX EDUCATION POWIAT:****

# %%
p1947 = pd.read_csv(repo_root / "cleaned/03_01_outcome_data/ru_sex_ed_p1947.csv", index_col=0)

# Drop total sex
p1947 = p1947[~(p1947["sex"]=="total")].copy()
# Drop total education 
p1947 = p1947[~(p1947["education"]=="total")].copy()

# Rename columns
p1947.rename(columns={"count": "ru"}, inplace=True)

# Create county_code
p1947["county_code"] = p1947["code"].apply(lambda x: int(str(x)[:-3]))

# Set index for join
p1947 = p1947.set_index(["county_code", "year", "sex", "education"])[["ru"]]

p1947
# Out:
#                                                                              ru
# county_code year sex     education
# 201         2000 males   tertiary                                           NaN
# 202         2000 males   tertiary                                           NaN
# 203         2000 males   tertiary                                           NaN
# 204         2000 males   tertiary                                           NaN
# 205         2000 males   tertiary                                           NaN
# ...                                                                         ...
# 3217        2025 females lower secondary, primary and incomplete primary  297.0
# 3218        2025 females lower secondary, primary and incomplete primary  280.0
# 3261        2025 females lower secondary, primary and incomplete primary  394.0
# 3262        2025 females lower secondary, primary and incomplete primary  647.0
# 3263        2025 females lower secondary, primary and incomplete primary   92.0
#
# [98800 rows x 1 columns]

# %% [markdown]
# **Table 1**
#
# All 5 education groups

# %%
pse1 = pd.read_csv(repo_root / "cleaned/03_01_outcome_tables/population_sex_ed_1.csv", index_col=0)

# Set index for join
pse1 = pse1.set_index(["county_code", "sex", "education"])

pse1
# Out:
#                                                                      pse1_nc_pop  \
# county_code sex     education
# 201         females basic vocational or basic sectoral vocational           8243
#                     general secondary                                       4880
#                     lower secondary, primary and incomplete primary         7847
#                     post-secondary and vocational secondary                 7365
#                     tertiary                                                8351
# ...                                                                          ...
# 3263        males   basic vocational or basic sectoral vocational           4008
#                     general secondary                                       2007
#                     lower secondary, primary and incomplete primary         2464
#                     post-secondary and vocational secondary                 4026
#                     tertiary                                                3337
#
#                                                                          county_kts  \
# county_code sex     education
# 201         females basic vocational or basic sectoral vocational    10030210101000
#                     general secondary                                10030210101000
#                     lower secondary, primary and incomplete primary  10030210101000
#                     post-secondary and vocational secondary          10030210101000
#                     tertiary                                         10030210101000
# ...                                                                             ...
# 3263        males   basic vocational or basic sectoral vocational    10023216663000
#                     general secondary                                10023216663000
#                     lower secondary, primary and incomplete primary  10023216663000
#                     post-secondary and vocational secondary          10023216663000
#                     tertiary                                         10023216663000
#
#                                                                                county_name
# county_code sex     education
# 201         females basic vocational or basic sectoral vocational     Powiat bolesławiecki
#                     general secondary                                 Powiat bolesławiecki
#                     lower secondary, primary and incomplete primary   Powiat bolesławiecki
#                     post-secondary and vocational secondary           Powiat bolesławiecki
#                     tertiary                                          Powiat bolesławiecki
# ...                                                                                    ...
# 3263        males   basic vocational or basic sectoral vocational    Powiat m. Świnoujście
#                     general secondary                                Powiat m. Świnoujście
#                     lower secondary, primary and incomplete primary  Powiat m. Świnoujście
#                     post-secondary and vocational secondary          Powiat m. Świnoujście
#                     tertiary                                         Powiat m. Świnoujście
#
# [3800 rows x 3 columns]

# %%
# Join
ru_se_table_1 = p1947.join(
    pse1,
    how="left"
)

# Reset index and save
ru_se_table_1 = ru_se_table_1.reset_index()
ru_se_table_1.to_csv(repo_root / "cleaned/03_01_outcome_tables/unemploy_sex_ed_1_table.csv")
ru_se_table_1
# Out:
#        county_code  year      sex  \
# 0              201  2000    males
# 1              202  2000    males
# 2              203  2000    males
# 3              204  2000    males
# 4              205  2000    males
# ...            ...   ...      ...
# 98795         3217  2025  females
# 98796         3218  2025  females
# 98797         3261  2025  females
# 98798         3262  2025  females
# 98799         3263  2025  females
#
#                                              education     ru  pse1_nc_pop  \
# 0                                             tertiary    NaN         5069
# 1                                             tertiary    NaN         5554
# 2                                             tertiary    NaN         6070
# 3                                             tertiary    NaN         1408
# 4                                             tertiary    NaN         2722
# ...                                                ...    ...          ...
# 98795  lower secondary, primary and incomplete primary  297.0         5171
# 98796  lower secondary, primary and incomplete primary  280.0         4169
# 98797  lower secondary, primary and incomplete primary  394.0         6795
# 98798  lower secondary, primary and incomplete primary  647.0        24389
# 98799  lower secondary, primary and incomplete primary   92.0         2946
#
#            county_kts            county_name
# 0      10030210101000   Powiat bolesławiecki
# 1      10030210302000  Powiat dzierżoniowski
# 2      10030210203000       Powiat głogowski
# 3      10030210204000        Powiat górowski
# 4      10030210105000        Powiat jaworski
# ...               ...                    ...
# 98795  10023216417000         Powiat wałecki
# 98796  10023216418000         Powiat łobeski
# 98797  10023216361000     Powiat m. Koszalin
# 98798  10023216562000     Powiat m. Szczecin
# 98799  10023216663000  Powiat m. Świnoujście
#
# [98800 rows x 8 columns]

# %% [markdown]
# **Table 2 - 2 and 4 joined - 4 total education groups:**

# %%
ru_se_table_2 = p1947.copy().reset_index()

# Drop na rows for ru
ru_se_table_2.dropna(subset=["ru"], inplace=True)

# First we need to group the education on ru
ru_se_table_2["education"] = ru_se_table_2["education"].replace(
    "general secondary", "general secondary and post-secondary"
)
ru_se_table_2["education"] = ru_se_table_2["education"].replace(
    "post-secondary and vocational secondary", "general secondary and post-secondary"
)
# Re group
ru_se_table_2 = ru_se_table_2.groupby(["county_code", "year", "sex", "education"])[["ru"]].sum()

ru_se_table_2
# Out:
#                                                                               ru
# county_code year sex     education
# 201         2004 females basic vocational or basic sectoral vocational    1340.0
#                          general secondary and post-secondary             1414.0
#                          lower secondary, primary and incomplete primary  1198.0
#                          tertiary                                          139.0
#                  males   basic vocational or basic sectoral vocational    1633.0
# ...                                                                          ...
# 3263        2025 females tertiary                                           46.0
#                  males   basic vocational or basic sectoral vocational      90.0
#                          general secondary and post-secondary              104.0
#                          lower secondary, primary and incomplete primary   168.0
#                          tertiary                                           36.0
#
# [66808 rows x 1 columns]

# %%
pse2 = pd.read_csv(repo_root / "cleaned/03_01_outcome_tables/population_sex_ed_2.csv", index_col=0)

pse2 = pse2.set_index(["county_code", "sex", "education"])

pse2
# Out:
#                                                                      pse1_nc_pop  \
# county_code sex     education
# 201         females basic vocational or basic sectoral vocational           8243
#                     general secondary and post-secondary                   12245
#                     lower secondary, primary and incomplete primary         7847
#                     tertiary                                                8351
#             males   basic vocational or basic sectoral vocational          11332
# ...                                                                          ...
# 3263        females tertiary                                                4664
#             males   basic vocational or basic sectoral vocational           4008
#                     general secondary and post-secondary                    6033
#                     lower secondary, primary and incomplete primary         2464
#                     tertiary                                                3337
#
#                                                                      pse2_nc_emp  \
# county_code sex     education
# 201         females basic vocational or basic sectoral vocational           3353
#                     general secondary and post-secondary                    7190
#                     lower secondary, primary and incomplete primary         1067
#                     tertiary                                                6085
#             males   basic vocational or basic sectoral vocational           6613
# ...                                                                          ...
# 3263        females tertiary                                                3260
#             males   basic vocational or basic sectoral vocational           1923
#                     general secondary and post-secondary                    3792
#                     lower secondary, primary and incomplete primary          633
#                     tertiary                                                2146
#
#                                                                          county_kts  \
# county_code sex     education
# 201         females basic vocational or basic sectoral vocational    10030210101000
#                     general secondary and post-secondary             10030210101000
#                     lower secondary, primary and incomplete primary  10030210101000
#                     tertiary                                         10030210101000
#             males   basic vocational or basic sectoral vocational    10030210101000
# ...                                                                             ...
# 3263        females tertiary                                         10023216663000
#             males   basic vocational or basic sectoral vocational    10023216663000
#                     general secondary and post-secondary             10023216663000
#                     lower secondary, primary and incomplete primary  10023216663000
#                     tertiary                                         10023216663000
#
#                                                                                county_name
# county_code sex     education
# 201         females basic vocational or basic sectoral vocational     Powiat bolesławiecki
#                     general secondary and post-secondary              Powiat bolesławiecki
#                     lower secondary, primary and incomplete primary   Powiat bolesławiecki
#                     tertiary                                          Powiat bolesławiecki
#             males   basic vocational or basic sectoral vocational     Powiat bolesławiecki
# ...                                                                                    ...
# 3263        females tertiary                                         Powiat m. Świnoujście
#             males   basic vocational or basic sectoral vocational    Powiat m. Świnoujście
#                     general secondary and post-secondary             Powiat m. Świnoujście
#                     lower secondary, primary and incomplete primary  Powiat m. Świnoujście
#                     tertiary                                         Powiat m. Świnoujście
#
# [3040 rows x 4 columns]

# %%
# Join
ru_se_table_2 = ru_se_table_2.join(
    pse2,
    how="left"
)

# Reset index and save
ru_se_table_2 = ru_se_table_2.reset_index()
ru_se_table_2.to_csv(repo_root / "cleaned/03_01_outcome_tables/unemploy_sex_ed_2_table.csv")
ru_se_table_2
# Out:
#        county_code  year      sex  \
# 0              201  2004  females
# 1              201  2004  females
# 2              201  2004  females
# 3              201  2004  females
# 4              201  2004    males
# ...            ...   ...      ...
# 66803         3263  2025  females
# 66804         3263  2025    males
# 66805         3263  2025    males
# 66806         3263  2025    males
# 66807         3263  2025    males
#
#                                              education      ru  pse1_nc_pop  \
# 0        basic vocational or basic sectoral vocational  1340.0         8243
# 1                 general secondary and post-secondary  1414.0        12245
# 2      lower secondary, primary and incomplete primary  1198.0         7847
# 3                                             tertiary   139.0         8351
# 4        basic vocational or basic sectoral vocational  1633.0        11332
# ...                                                ...     ...          ...
# 66803                                         tertiary    46.0         4664
# 66804    basic vocational or basic sectoral vocational    90.0         4008
# 66805             general secondary and post-secondary   104.0         6033
# 66806  lower secondary, primary and incomplete primary   168.0         2464
# 66807                                         tertiary    36.0         3337
#
#        pse2_nc_emp      county_kts            county_name
# 0             3353  10030210101000   Powiat bolesławiecki
# 1             7190  10030210101000   Powiat bolesławiecki
# 2             1067  10030210101000   Powiat bolesławiecki
# 3             6085  10030210101000   Powiat bolesławiecki
# 4             6613  10030210101000   Powiat bolesławiecki
# ...            ...             ...                    ...
# 66803         3260  10023216663000  Powiat m. Świnoujście
# 66804         1923  10023216663000  Powiat m. Świnoujście
# 66805         3792  10023216663000  Powiat m. Świnoujście
# 66806          633  10023216663000  Powiat m. Świnoujście
# 66807         2146  10023216663000  Powiat m. Świnoujście
#
# [66808 rows x 9 columns]
