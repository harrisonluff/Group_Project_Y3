# %%
import sys
from pathlib import Path

p = Path.cwd().resolve()
repo_root = next((parent for parent in [p] + list(p.parents) if (parent / ".git").exists()), None)
if repo_root is None:
    raise RuntimeError("Repo root not found. Open the repo folder in VS Code.")

sys.path.insert(0, str(repo_root))
print("Repo root:", repo_root)
# Out:
# Repo root: C:\Users\harri\OneDrive - Imperial College London\Year 3 Group Project\Group_Project_Y3

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **A - National Census 2021:**
#
# Cleaning P4181 - Population by age and sex

# %%
pop_nc_as = pd.read_csv(repo_root / "raw/03_01_population_data/03_01_census_p4181_pop_sex_age.csv", delimiter=";")
pop_nc_as.head()
# Out:
#      Code                   Name  total;total;2021;[person]  \
# 0  201000   Powiat bolesławiecki                      88435
# 1  202000  Powiat dzierżoniowski                      97721
# 2  203000       Powiat głogowski                      86668
# 3  204000        Powiat górowski                      33317
# 4  205000        Powiat jaworski                      48503
#
#    total;0;2021;[person]  total;1;2021;[person]  total;2;2021;[person]  \
# 0                    718                    799                    891
# 1                    658                    747                    791
# 2                    705                    764                    769
# 3                    275                    325                    297
# 4                    397                    425                    413
#
#    total;3;2021;[person]  total;4;2021;[person]  total;5;2021;[person]  \
# 0                    910                    949                    886
# 1                    886                    877                    829
# 2                    832                    848                    848
# 3                    356                    307                    300
# 4                    447                    457                    460
#
#    total;6;2021;[person]  ...  females;82;2021;[person]  \
# 0                    899  ...                       244
# 1                    873  ...                       368
# 2                    885  ...                       177
# 3                    320  ...                        73
# 4                    458  ...                       126
#
#    females;83;2021;[person]  females;84;2021;[person]  \
# 0                       273                       215
# 1                       391                       347
# 2                       198                       193
# 3                        92                        87
# 4                       128                       118
#
#    females;85;2021;[person]  females;86;2021;[person]  \
# 0                       222                       222
# 1                       317                       258
# 2                       171                       141
# 3                        89                        79
# 4                       126                       106
#
#    females;87;2021;[person]  females;88;2021;[person]  \
# 0                       173                       135
# 1                       246                       228
# 2                       117                        89
# 3                        63                        69
# 4                       117                        82
#
#    females;89;2021;[person]  females;90 and more;2021;[person]  Unnamed: 278
# 0                       127                                419           NaN
# 1                       205                                768           NaN
# 2                        88                                304           NaN
# 3                        53                                175           NaN
# 4                        87                                285           NaN
#
# [5 rows x 279 columns]

# %%
df = pop_nc_as.copy()

# Drop unnamed column
df.drop("Unnamed: 278", axis=1, inplace=True)

# Melt to long format
id_cols = ["Code", "Name"]
long = df.melt(
    id_vars=id_cols, 
    var_name="measure",
    value_name="count"
)

# Split measure into parts
parts = long["measure"].str.split(";", expand=True)
long["sex"] = parts[0].str.strip()
long["age"] = parts[1].str.strip()
long["year"] = pd.to_numeric(parts[2]).astype("Int64")

out = long.rename(
        columns={"Code": "code", "Name": "powiat"}
    ).loc[
        :, ["code", "powiat", "year", "sex", "age", "count"]
    ]

out.to_csv(repo_root / "cleaned/03_01_outcome_data/pop_nc_sex_age_p4181.csv")

# %% [markdown]
# Cleaning P4315 - Population aged 13 years and more by educational level and sex

# %%
pop_nc_se = pd.read_csv(repo_root / "raw/03_01_population_data/03_01_census_p4315_pop_sex_ed.csv", delimiter=";")
pop_nc_se.head()
# Out:
#      Code                   Name  total;total;2021;[person]  \
# 0  201000   Powiat bolesławiecki                      76739
# 1  202000  Powiat dzierżoniowski                      86543
# 2  203000       Powiat głogowski                      75191
# 3  204000        Powiat górowski                      29042
# 4  205000        Powiat jaworski                      42493
#
#    total;tertiary;2021;[person]  \
# 0                         13420
# 1                         14680
# 2                         15725
# 3                          3962
# 4                          7222
#
#    total;secondary and post-secondary - total;2021;[person]  \
# 0                                              26886
# 1                                              31483
# 2                                              27891
# 3                                               9693
# 4                                              14572
#
#    total;secondary and post-secondary - general secondary;2021;[person]  \
# 0                                               7994
# 1                                               9645
# 2                                               8358
# 3                                               2563
# 4                                               4547
#
#    total;secondary and post-secondary - vocational secondary;2021;[person]  \
# 0                                              16114
# 1                                              18302
# 2                                              16723
# 3                                               6148
# 4                                               8554
#
#    total;basic vocational/sectoral;2021;[person]  \
# 0                                          19575
# 1                                          19891
# 2                                          17123
# 3                                           8087
# 4                                          11316
#
#    total;lower secondary;2021;[person]  total;primary completed;2021;[person]  \
# 0                                 2207                                   9772
# 1                                 2415                                  11947
# 2                                 2175                                   7877
# 3                                 1091                                   4556
# 4                                 1224                                   5524
#
#    ...  females;tertiary;2021;[person]  \
# 0  ...                            8351
# 1  ...                            9126
# 2  ...                            9655
# 3  ...                            2554
# 4  ...                            4500
#
#    females;secondary and post-secondary - total;2021;[person]  \
# 0                                              14231
# 1                                              17048
# 2                                              14637
# 3                                               5162
# 4                                               7931
#
#    females;secondary and post-secondary - general secondary;2021;[person]  \
# 0                                               4880
# 1                                               5911
# 2                                               5201
# 3                                               1591
# 4                                               2830
#
#    females;secondary and post-secondary - vocational secondary;2021;[person]  \
# 0                                               7365
# 1                                               8710
# 2                                               7429
# 3                                               2915
# 4                                               4059
#
#    females;basic vocational/sectoral;2021;[person]  \
# 0                                             8243
# 1                                             8811
# 2                                             7037
# 3                                             3185
# 4                                             4521
#
#    females;lower secondary;2021;[person]  \
# 0                                    985
# 1                                   1035
# 2                                    912
# 3                                    434
# 4                                    499
#
#    females;primary completed;2021;[person]  \
# 0                                     5646
# 1                                     6689
# 2                                     4626
# 3                                     2535
# 4                                     3088
#
#    females;primary not completed and without school education;2021;[person]  \
# 0                                               1216
# 1                                               1350
# 2                                               1247
# 3                                                487
# 4                                                667
#
#    females;unknown;2021;[person]  Unnamed: 32
# 0                           1154          NaN
# 1                           1765          NaN
# 2                            878          NaN
# 3                            318          NaN
# 4                            598          NaN
#
# [5 rows x 33 columns]

# %%
df = pop_nc_se.copy()

# Drop unnamed column
df.drop("Unnamed: 32", axis=1, inplace=True)

# Melt to long format
id_cols = ["Code", "Name"]
long = df.melt(
    id_vars=id_cols, 
    var_name="measure",
    value_name="count"
)

# Split measure into parts
parts = long["measure"].str.split(";", expand=True)
long["sex"] = parts[0].str.strip()
long["education"] = parts[1].str.strip()
long["year"] = pd.to_numeric(parts[2]).astype("Int64")

out = long.rename(
        columns={"Code": "code", "Name": "powiat"}
    ).loc[
        :, ["code", "powiat", "year", "sex", "education", "count"]
    ]

out.to_csv(repo_root / "cleaned/03_01_outcome_data/pop_nc_sex_ed_p4315.csv")

# %% [markdown]
# **B - National Census 2021:**
#
# Cleaning P4407 - Employed by age and sex

# %%
emp_sa = pd.read_csv(repo_root / "raw/03_01_population_data/03_01_census_p4407_employed_sex_age.csv", delimiter=";")
emp_sa.head()
# Out:
#      Code                   Name  total;total;2021;[person]  \
# 0  201000   Powiat bolesławiecki                      38792
# 1  202000  Powiat dzierżoniowski                      39657
# 2  203000       Powiat głogowski                      36209
# 3  204000        Powiat górowski                      13765
# 4  205000        Powiat jaworski                      20715
#
#    total;15-24;2021;[person]  total;25-34;2021;[person]  \
# 0                       3268                       8658
# 1                       3249                       8023
# 2                       2678                       7711
# 3                       1385                       2859
# 4                       1600                       4232
#
#    total;35-44;2021;[person]  total;45-54;2021;[person]  \
# 0                      10510                       8577
# 1                      11025                       8860
# 2                      11170                       8054
# 3                       3567                       3157
# 4                       5719                       4596
#
#    total;55-64;2021;[person]  total;65 and more;2021;[person]  \
# 0                       6316                             1463
# 1                       6900                             1600
# 2                       5261                             1335
# 3                       2337                              460
# 4                       3768                              800
#
#    males;total;2021;[person]  ...  males;55-64;2021;[person]  \
# 0                      20869  ...                       3634
# 1                      21238  ...                       4037
# 2                      19946  ...                       2969
# 3                       7834  ...                       1416
# 4                      11289  ...                       2220
#
#    males;65 and more;2021;[person]  females;total;2021;[person]  \
# 0                              863                        17923
# 1                              968                        18419
# 2                              804                        16263
# 3                              309                         5931
# 4                              483                         9426
#
#    females;15-24;2021;[person]  females;25-34;2021;[person]  \
# 0                         1431                         4012
# 1                         1483                         3813
# 2                         1187                         3425
# 3                          565                         1206
# 4                          713                         1886
#
#    females;35-44;2021;[person]  females;45-54;2021;[person]  \
# 0                         4946                         4252
# 1                         5240                         4388
# 2                         5022                         3806
# 3                         1617                         1471
# 4                         2711                         2251
#
#    females;55-64;2021;[person]  females;65 and more;2021;[person]  Unnamed: 23
# 0                         2682                                600          NaN
# 1                         2863                                632          NaN
# 2                         2292                                531          NaN
# 3                          921                                151          NaN
# 4                         1548                                317          NaN
#
# [5 rows x 24 columns]

# %%
df = emp_sa.copy()

# Drop unnamed column
df.drop("Unnamed: 23", axis=1, inplace=True)

# Melt to long format
id_cols = ["Code", "Name"]
long = df.melt(
    id_vars=id_cols, 
    var_name="measure",
    value_name="count"
)

# Split measure into parts
parts = long["measure"].str.split(";", expand=True)
long["sex"] = parts[0].str.strip()
long["age"] = parts[1].str.strip()
long["year"] = pd.to_numeric(parts[2]).astype("Int64")

out = long.rename(
        columns={"Code": "code", "Name": "powiat"}
    ).loc[
        :, ["code", "powiat", "year", "sex", "age", "count"]
    ]

out.to_csv(repo_root / "cleaned/03_01_outcome_data/emp_nc_sex_age_p4407.csv")

# %% [markdown]
# Cleaning P4303 - Employed by sex and education

# %%
emp_se = pd.read_csv(repo_root / "raw/03_01_population_data/03_01_census_p4303_employed_sex_ed.csv", delimiter=";")
emp_se.head()
# Out:
#      Code                   Name  total;total;2021;[person]  \
# 0  201000   Powiat bolesławiecki                      38792
# 1  202000  Powiat dzierżoniowski                      39657
# 2  203000       Powiat głogowski                      36209
# 3  204000        Powiat górowski                      13765
# 4  205000        Powiat jaworski                      20715
#
#    total;tertiary;2021;[person]  \
# 0                          9881
# 1                         10204
# 2                         11926
# 3                          2875
# 4                          5344
#
#    total;secondary and post-secondary - total;2021;[person]  \
# 0                                              15604
# 1                                              16804
# 2                                              15055
# 3                                               5454
# 4                                               8030
#
#    total;basic vocational/sectoral;2021;[person]  \
# 0                                           9966
# 1                                           8663
# 2                                           7129
# 3                                           4083
# 4                                           5648
#
#    total;lower secondary, primary, primary not completed and without school education;2021;[person]  \
# 0                                               2712
# 1                                               3253
# 2                                               1688
# 3                                               1222
# 4                                               1421
#
#    males;total;2021;[person]  males;tertiary;2021;[person]  \
# 0                      20869                          3796
# 1                      21238                          3837
# 2                      19946                          4777
# 3                       7834                          1037
# 4                      11289                          2051
#
#    males;secondary and post-secondary - total;2021;[person]  \
# 0                                               8414
# 1                                               8992
# 2                                               8697
# 3                                               3008
# 4                                               4278
#
#    males;basic vocational/sectoral;2021;[person]  \
# 0                                           6613
# 1                                           5807
# 2                                           5093
# 3                                           2879
# 4                                           3862
#
#    males;lower secondary, primary, primary not completed and without school education;2021;[person]  \
# 0                                               1645
# 1                                               2137
# 2                                               1086
# 3                                                826
# 4                                                919
#
#    females;total;2021;[person]  females;tertiary;2021;[person]  \
# 0                        17923                            6085
# 1                        18419                            6367
# 2                        16263                            7149
# 3                         5931                            1838
# 4                         9426                            3293
#
#    females;secondary and post-secondary - total;2021;[person]  \
# 0                                               7190
# 1                                               7812
# 2                                               6358
# 3                                               2446
# 4                                               3752
#
#    females;basic vocational/sectoral;2021;[person]  \
# 0                                             3353
# 1                                             2856
# 2                                             2036
# 3                                             1204
# 4                                             1786
#
#    females;lower secondary, primary, primary not completed and without school education;2021;[person]  \
# 0                                               1067
# 1                                               1116
# 2                                                602
# 3                                                396
# 4                                                502
#
#    Unnamed: 17
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df = emp_se.copy()

# Drop unnamed column
df.drop("Unnamed: 17", axis=1, inplace=True)

# Melt to long format
id_cols = ["Code", "Name"]
long = df.melt(
    id_vars=id_cols, 
    var_name="measure",
    value_name="count"
)

# Split measure into parts
parts = long["measure"].str.split(";", expand=True)
long["sex"] = parts[0].str.strip()
long["education"] = parts[1].str.strip()
long["year"] = pd.to_numeric(parts[2]).astype("Int64")

out = long.rename(
        columns={"Code": "code", "Name": "powiat"}
    ).loc[
        :, ["code", "powiat", "year", "sex", "education", "count"]
    ]

out.to_csv(repo_root / "cleaned/03_01_outcome_data/emp_nc_sex_ed_p4303.csv")
