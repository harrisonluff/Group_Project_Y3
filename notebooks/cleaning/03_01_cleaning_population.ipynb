# %%
import sys
from pathlib import Path

p = Path.cwd().resolve()
repo_root = next((parent for parent in [p] + list(p.parents) if (parent / ".git").exists()), None)
if repo_root is None:
    raise RuntimeError("Repo root not found. Open the repo folder in VS Code.")

sys.path.insert(0, str(repo_root))
print("Repo root:", repo_root)
# Out:
# Repo root: C:\Users\harri\OneDrive - Imperial College London\Year 3 Group Project\Group_Project_Y3

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **A - National Census 2021:**
#
# Cleaning P4181 - Population by age and sex

# %%
pop_nc_as = pd.read_csv(repo_root / "raw/03_01_population_data/03_01_census_p4181_pop_sex_age.csv", delimiter=";")
pop_nc_as.head()
# Out:
#      Code                   Name  total;total;2021;[person]  \
# 0  201000   Powiat bolesławiecki                      88435
# 1  202000  Powiat dzierżoniowski                      97721
# 2  203000       Powiat głogowski                      86668
# 3  204000        Powiat górowski                      33317
# 4  205000        Powiat jaworski                      48503
#
#    total;0;2021;[person]  total;1;2021;[person]  total;2;2021;[person]  \
# 0                    718                    799                    891
# 1                    658                    747                    791
# 2                    705                    764                    769
# 3                    275                    325                    297
# 4                    397                    425                    413
#
#    total;3;2021;[person]  total;4;2021;[person]  total;5;2021;[person]  \
# 0                    910                    949                    886
# 1                    886                    877                    829
# 2                    832                    848                    848
# 3                    356                    307                    300
# 4                    447                    457                    460
#
#    total;6;2021;[person]  ...  females;82;2021;[person]  \
# 0                    899  ...                       244
# 1                    873  ...                       368
# 2                    885  ...                       177
# 3                    320  ...                        73
# 4                    458  ...                       126
#
#    females;83;2021;[person]  females;84;2021;[person]  \
# 0                       273                       215
# 1                       391                       347
# 2                       198                       193
# 3                        92                        87
# 4                       128                       118
#
#    females;85;2021;[person]  females;86;2021;[person]  \
# 0                       222                       222
# 1                       317                       258
# 2                       171                       141
# 3                        89                        79
# 4                       126                       106
#
#    females;87;2021;[person]  females;88;2021;[person]  \
# 0                       173                       135
# 1                       246                       228
# 2                       117                        89
# 3                        63                        69
# 4                       117                        82
#
#    females;89;2021;[person]  females;90 and more;2021;[person]  Unnamed: 278
# 0                       127                                419           NaN
# 1                       205                                768           NaN
# 2                        88                                304           NaN
# 3                        53                                175           NaN
# 4                        87                                285           NaN
#
# [5 rows x 279 columns]

# %%
df = pop_nc_as.copy()

# Drop unnamed column
df.drop("Unnamed: 278", axis=1, inplace=True)

# Melt to long format
id_cols = ["Code", "Name"]
long = df.melt(
    id_vars=id_cols, 
    var_name="measure",
    value_name="count"
)

# Split measure into parts
parts = long["measure"].str.split(";", expand=True)
long["sex"] = parts[0].str.strip()
long["age"] = parts[1].str.strip()
long["year"] = pd.to_numeric(parts[2]).astype("Int64")

out = long.rename(
        columns={"Code": "code", "Name": "powiat"}
    ).loc[
        :, ["code", "powiat", "year", "sex", "age", "count"]
    ]

out.to_csv(repo_root / "cleaned/03_01_outcome_data/pop_nc_sex_age_p4181.csv")

# %% [markdown]
# Cleaning P4315 - Population aged 13 years and more by educational level and sex

# %%
pop_nc_se = pd.read_csv(repo_root / "raw/03_01_population_data/03_01_census_p4315_pop_sex_ed.csv", delimiter=";")
pop_nc_se.head()
# Out:
#      Code                   Name  total;total;2021;[person]  \
# 0  201000   Powiat bolesławiecki                      76739
# 1  202000  Powiat dzierżoniowski                      86543
# 2  203000       Powiat głogowski                      75191
# 3  204000        Powiat górowski                      29042
# 4  205000        Powiat jaworski                      42493
#
#    total;tertiary;2021;[person]  \
# 0                         13420
# 1                         14680
# 2                         15725
# 3                          3962
# 4                          7222
#
#    total;secondary and post-secondary - total;2021;[person]  \
# 0                                              26886
# 1                                              31483
# 2                                              27891
# 3                                               9693
# 4                                              14572
#
#    total;secondary and post-secondary - general secondary;2021;[person]  \
# 0                                               7994
# 1                                               9645
# 2                                               8358
# 3                                               2563
# 4                                               4547
#
#    total;secondary and post-secondary - vocational secondary;2021;[person]  \
# 0                                              16114
# 1                                              18302
# 2                                              16723
# 3                                               6148
# 4                                               8554
#
#    total;basic vocational/sectoral;2021;[person]  \
# 0                                          19575
# 1                                          19891
# 2                                          17123
# 3                                           8087
# 4                                          11316
#
#    total;lower secondary;2021;[person]  total;primary completed;2021;[person]  \
# 0                                 2207                                   9772
# 1                                 2415                                  11947
# 2                                 2175                                   7877
# 3                                 1091                                   4556
# 4                                 1224                                   5524
#
#    ...  females;tertiary;2021;[person]  \
# 0  ...                            8351
# 1  ...                            9126
# 2  ...                            9655
# 3  ...                            2554
# 4  ...                            4500
#
#    females;secondary and post-secondary - total;2021;[person]  \
# 0                                              14231
# 1                                              17048
# 2                                              14637
# 3                                               5162
# 4                                               7931
#
#    females;secondary and post-secondary - general secondary;2021;[person]  \
# 0                                               4880
# 1                                               5911
# 2                                               5201
# 3                                               1591
# 4                                               2830
#
#    females;secondary and post-secondary - vocational secondary;2021;[person]  \
# 0                                               7365
# 1                                               8710
# 2                                               7429
# 3                                               2915
# 4                                               4059
#
#    females;basic vocational/sectoral;2021;[person]  \
# 0                                             8243
# 1                                             8811
# 2                                             7037
# 3                                             3185
# 4                                             4521
#
#    females;lower secondary;2021;[person]  \
# 0                                    985
# 1                                   1035
# 2                                    912
# 3                                    434
# 4                                    499
#
#    females;primary completed;2021;[person]  \
# 0                                     5646
# 1                                     6689
# 2                                     4626
# 3                                     2535
# 4                                     3088
#
#    females;primary not completed and without school education;2021;[person]  \
# 0                                               1216
# 1                                               1350
# 2                                               1247
# 3                                                487
# 4                                                667
#
#    females;unknown;2021;[person]  Unnamed: 32
# 0                           1154          NaN
# 1                           1765          NaN
# 2                            878          NaN
# 3                            318          NaN
# 4                            598          NaN
#
# [5 rows x 33 columns]

# %%
df = pop_nc_se.copy()

# Drop unnamed column
df.drop("Unnamed: 32", axis=1, inplace=True)

# Melt to long format
id_cols = ["Code", "Name"]
long = df.melt(
    id_vars=id_cols, 
    var_name="measure",
    value_name="count"
)

# Split measure into parts
parts = long["measure"].str.split(";", expand=True)
long["sex"] = parts[0].str.strip()
long["education"] = parts[1].str.strip()
long["year"] = pd.to_numeric(parts[2]).astype("Int64")

out = long.rename(
        columns={"Code": "code", "Name": "powiat"}
    ).loc[
        :, ["code", "powiat", "year", "sex", "education", "count"]
    ]

out.to_csv(repo_root / "cleaned/03_01_outcome_data/pop_nc_sex_ed_p4315.csv")

# %% [markdown]
# **B - National Census 2021:**
#
# Cleaning P4407 - Employed by age and sex

# %%
emp_sa = pd.read_csv(repo_root / "raw/03_01_population_data/03_01_census_p4407_employed_sex_age.csv", delimiter=";")
emp_sa.head()
# Out:
#      Code                   Name  total;total;2021;[person]  \
# 0  201000   Powiat bolesławiecki                      38792
# 1  202000  Powiat dzierżoniowski                      39657
# 2  203000       Powiat głogowski                      36209
# 3  204000        Powiat górowski                      13765
# 4  205000        Powiat jaworski                      20715
#
#    total;15-24;2021;[person]  total;25-34;2021;[person]  \
# 0                       3268                       8658
# 1                       3249                       8023
# 2                       2678                       7711
# 3                       1385                       2859
# 4                       1600                       4232
#
#    total;35-44;2021;[person]  total;45-54;2021;[person]  \
# 0                      10510                       8577
# 1                      11025                       8860
# 2                      11170                       8054
# 3                       3567                       3157
# 4                       5719                       4596
#
#    total;55-64;2021;[person]  total;65 and more;2021;[person]  \
# 0                       6316                             1463
# 1                       6900                             1600
# 2                       5261                             1335
# 3                       2337                              460
# 4                       3768                              800
#
#    males;total;2021;[person]  ...  males;55-64;2021;[person]  \
# 0                      20869  ...                       3634
# 1                      21238  ...                       4037
# 2                      19946  ...                       2969
# 3                       7834  ...                       1416
# 4                      11289  ...                       2220
#
#    males;65 and more;2021;[person]  females;total;2021;[person]  \
# 0                              863                        17923
# 1                              968                        18419
# 2                              804                        16263
# 3                              309                         5931
# 4                              483                         9426
#
#    females;15-24;2021;[person]  females;25-34;2021;[person]  \
# 0                         1431                         4012
# 1                         1483                         3813
# 2                         1187                         3425
# 3                          565                         1206
# 4                          713                         1886
#
#    females;35-44;2021;[person]  females;45-54;2021;[person]  \
# 0                         4946                         4252
# 1                         5240                         4388
# 2                         5022                         3806
# 3                         1617                         1471
# 4                         2711                         2251
#
#    females;55-64;2021;[person]  females;65 and more;2021;[person]  Unnamed: 23
# 0                         2682                                600          NaN
# 1                         2863                                632          NaN
# 2                         2292                                531          NaN
# 3                          921                                151          NaN
# 4                         1548                                317          NaN
#
# [5 rows x 24 columns]

# %%
df = emp_sa.copy()

# Drop unnamed column
df.drop("Unnamed: 23", axis=1, inplace=True)

# Melt to long format
id_cols = ["Code", "Name"]
long = df.melt(
    id_vars=id_cols, 
    var_name="measure",
    value_name="count"
)

# Split measure into parts
parts = long["measure"].str.split(";", expand=True)
long["sex"] = parts[0].str.strip()
long["age"] = parts[1].str.strip()
long["year"] = pd.to_numeric(parts[2]).astype("Int64")

out = long.rename(
        columns={"Code": "code", "Name": "powiat"}
    ).loc[
        :, ["code", "powiat", "year", "sex", "age", "count"]
    ]

out.to_csv(repo_root / "cleaned/03_01_outcome_data/emp_nc_sex_age_p4407.csv")

# %% [markdown]
# Cleaning P4303 - Employed by sex and education

# %%
emp_se = pd.read_csv(repo_root / "raw/03_01_population_data/03_01_census_p4303_employed_sex_ed.csv", delimiter=";")
emp_se.head()
# Out:
#      Code                   Name  total;total;2021;[person]  \
# 0  201000   Powiat bolesławiecki                      38792
# 1  202000  Powiat dzierżoniowski                      39657
# 2  203000       Powiat głogowski                      36209
# 3  204000        Powiat górowski                      13765
# 4  205000        Powiat jaworski                      20715
#
#    total;tertiary;2021;[person]  \
# 0                          9881
# 1                         10204
# 2                         11926
# 3                          2875
# 4                          5344
#
#    total;secondary and post-secondary - total;2021;[person]  \
# 0                                              15604
# 1                                              16804
# 2                                              15055
# 3                                               5454
# 4                                               8030
#
#    total;basic vocational/sectoral;2021;[person]  \
# 0                                           9966
# 1                                           8663
# 2                                           7129
# 3                                           4083
# 4                                           5648
#
#    total;lower secondary, primary, primary not completed and without school education;2021;[person]  \
# 0                                               2712
# 1                                               3253
# 2                                               1688
# 3                                               1222
# 4                                               1421
#
#    males;total;2021;[person]  males;tertiary;2021;[person]  \
# 0                      20869                          3796
# 1                      21238                          3837
# 2                      19946                          4777
# 3                       7834                          1037
# 4                      11289                          2051
#
#    males;secondary and post-secondary - total;2021;[person]  \
# 0                                               8414
# 1                                               8992
# 2                                               8697
# 3                                               3008
# 4                                               4278
#
#    males;basic vocational/sectoral;2021;[person]  \
# 0                                           6613
# 1                                           5807
# 2                                           5093
# 3                                           2879
# 4                                           3862
#
#    males;lower secondary, primary, primary not completed and without school education;2021;[person]  \
# 0                                               1645
# 1                                               2137
# 2                                               1086
# 3                                                826
# 4                                                919
#
#    females;total;2021;[person]  females;tertiary;2021;[person]  \
# 0                        17923                            6085
# 1                        18419                            6367
# 2                        16263                            7149
# 3                         5931                            1838
# 4                         9426                            3293
#
#    females;secondary and post-secondary - total;2021;[person]  \
# 0                                               7190
# 1                                               7812
# 2                                               6358
# 3                                               2446
# 4                                               3752
#
#    females;basic vocational/sectoral;2021;[person]  \
# 0                                             3353
# 1                                             2856
# 2                                             2036
# 3                                             1204
# 4                                             1786
#
#    females;lower secondary, primary, primary not completed and without school education;2021;[person]  \
# 0                                               1067
# 1                                               1116
# 2                                                602
# 3                                                396
# 4                                                502
#
#    Unnamed: 17
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df = emp_se.copy()

# Drop unnamed column
df.drop("Unnamed: 17", axis=1, inplace=True)

# Melt to long format
id_cols = ["Code", "Name"]
long = df.melt(
    id_vars=id_cols, 
    var_name="measure",
    value_name="count"
)

# Split measure into parts
parts = long["measure"].str.split(";", expand=True)
long["sex"] = parts[0].str.strip()
long["education"] = parts[1].str.strip()
long["year"] = pd.to_numeric(parts[2]).astype("Int64")

out = long.rename(
        columns={"Code": "code", "Name": "powiat"}
    ).loc[
        :, ["code", "powiat", "year", "sex", "education", "count"]
    ]

out.to_csv(repo_root / "cleaned/03_01_outcome_data/emp_nc_sex_ed_p4303.csv")

# %% [markdown]
# **C - Population by sex-age by powiat - P2137**

# %%
pop_sa_yr = pd.read_csv(repo_root / "raw/03_01_population_data/03_01_pop_p2137_sex_agegr.csv", delimiter=";")
pop_sa_yr.head()
# Out:
#      Code                   Name  total;total;1995;[person]  \
# 0  201000   Powiat bolesławiecki                    89407.0
# 1  202000  Powiat dzierżoniowski                   113810.0
# 2  203000       Powiat głogowski                    91373.0
# 3  204000        Powiat górowski                    37826.0
# 4  205000        Powiat jaworski                    54914.0
#
#    total;total;1996;[person]  total;total;1997;[person]  \
# 0                    89411.0                    89596.0
# 1                   113323.0                   112857.0
# 2                    91590.0                    91656.0
# 3                    37781.0                    37976.0
# 4                    54829.0                    54921.0
#
#    total;total;1998;[person]  total;total;1999;[person]  \
# 0                    89590.0                    87740.0
# 1                   112466.0                   107810.0
# 2                    91636.0                    87962.0
# 3                    38017.0                    36821.0
# 4                    54818.0                    53105.0
#
#    total;total;2000;[person]  total;total;2001;[person]  \
# 0                    88005.0                    88121.0
# 1                   107424.0                   107112.0
# 2                    88092.0                    88181.0
# 3                    36924.0                    36789.0
# 4                    53116.0                    52874.0
#
#    total;total;2002;[person]  ...  0-14;females;2016;[person]  \
# 0                    88132.0  ...                      6543.0
# 1                   106479.0  ...                      6508.0
# 2                    87868.0  ...                      6835.0
# 3                    36817.0  ...                      2660.0
# 4                    52634.0  ...                      3437.0
#
#    0-14;females;2017;[person]  0-14;females;2018;[person]  \
# 0                      6562.0                      6575.0
# 1                      6502.0                      6477.0
# 2                      6791.0                      6786.0
# 3                      2622.0                      2576.0
# 4                      3486.0                      3474.0
#
#    0-14;females;2019;[person]  0-14;females;2020;[person]  \
# 0                      6586.0                      6598.0
# 1                      6474.0                      6448.0
# 2                      6713.0                      6661.0
# 3                      2533.0                      2445.0
# 4                      3392.0                      3432.0
#
#    0-14;females;2021;[person]  0-14;females;2022;[person]  \
# 0                      6567.0                      6427.0
# 1                      6336.0                      6174.0
# 2                      6532.0                      6300.0
# 3                      2412.0                      2353.0
# 4                      3361.0                      3267.0
#
#    0-14;females;2023;[person]  0-14;females;2024;[person]  Unnamed: 1892
# 0                      6242.0                      5988.0            NaN
# 1                      5947.0                      5663.0            NaN
# 2                      6002.0                      5720.0            NaN
# 3                      2278.0                      2194.0            NaN
# 4                      3127.0                      2968.0            NaN
#
# [5 rows x 1893 columns]

# %%
df = pop_sa_yr.copy()

# Drop unnamed column
df.drop("Unnamed: 1892", axis=1, inplace=True)

# Melt to long format
id_cols = ["Code", "Name"]
long = df.melt(
    id_vars=id_cols, 
    var_name="measure",
    value_name="count"
)

# Split measure into parts
parts = long["measure"].str.split(";", expand=True)
long["age_group"] = parts[0].str.strip()
long["sex"] = parts[1].str.strip()
long["year"] = pd.to_numeric(parts[2]).astype("Int64")

out = long.rename(
        columns={"Code": "code", "Name": "powiat"}
    ).loc[
        :, ["code", "powiat", "year", "sex", "age_group", "count"]
    ]

out.to_csv(repo_root / "cleaned/03_01_outcome_data/pop_yr_sex_agegr_p2137.csv")

# %% [markdown]
# **D - National Census Activity Table**
#
# Cleaning p4292 - economic activity of the population aged 15 years and more by sex and the place of residence

# %%
ec_ac_table = pd.read_csv(repo_root / "raw/03_01_population_data/03_01_census_p4292_activity_table.csv", delimiter=";")
ec_ac_table.head()
# Out:
#      Code                   Name  total;total;total;2021;[person]  \
# 0  201000   Powiat bolesławiecki                            74863
# 1  202000  Powiat dzierżoniowski                            84726
# 2  203000       Powiat głogowski                            73213
# 3  204000        Powiat górowski                            28309
# 4  205000        Powiat jaworski                            41503
#
#    total;total;economically active population;2021;[person]  \
# 0                                              40280
# 1                                              41553
# 2                                              37825
# 3                                              14860
# 4                                              21874
#
#    total;total;employed;2021;[person]  total;total;unemployed;2021;[person]  \
# 0                               38792                                  1488
# 1                               39657                                  1896
# 2                               36209                                  1616
# 3                               13765                                  1095
# 4                               20715                                  1159
#
#    total;total;economically inactive persons;2021;[person]  \
# 0                                              28735
# 1                                              34095
# 2                                              30649
# 3                                              11769
# 4                                              16512
#
#    total;total;unidentified status on the labour market;2021;[person]  \
# 0                                               5848
# 1                                               9078
# 2                                               4739
# 3                                               1680
# 4                                               3117
#
#    total;total;activity rate;2021;[%]  total;total;employment rate;2021;[%]  \
# 0                                58.4                                  56.2
# 1                                54.9                                  52.4
# 2                                55.2                                  52.9
# 3                                55.8                                  51.7
# 4                                57.0                                  54.0
#
#    ...  total;females;total;2021;[person]  \
# 0  ...                              38908
# 1  ...                              44920
# 2  ...                              37995
# 3  ...                              14336
# 4  ...                              21331
#
#    total;females;economically active population;2021;[person]  \
# 0                                              18598
# 1                                              19229
# 2                                              17168
# 3                                               6452
# 4                                               9899
#
#    total;females;employed;2021;[person]  \
# 0                                 17923
# 1                                 18419
# 2                                 16263
# 3                                  5931
# 4                                  9426
#
#    total;females;unemployed;2021;[person]  \
# 0                                     675
# 1                                     810
# 2                                     905
# 3                                     521
# 4                                     473
#
#    total;females;economically inactive persons;2021;[person]  \
# 0                                              17553
# 1                                              21278
# 2                                              18545
# 3                                               7089
# 4                                               9948
#
#    total;females;unidentified status on the labour market;2021;[person]  \
# 0                                               2757
# 1                                               4413
# 2                                               2282
# 3                                                795
# 4                                               1484
#
#    total;females;activity rate;2021;[%]  \
# 0                                  51.4
# 1                                  47.5
# 2                                  48.1
# 3                                  47.6
# 4                                  49.9
#
#    total;females;employment rate;2021;[%]  \
# 0                                    49.6
# 1                                    45.5
# 2                                    45.5
# 3                                    43.8
# 4                                    47.5
#
#    total;females;unemployment rate;2021;[%]  Unnamed: 29
# 0                                       3.6          NaN
# 1                                       4.2          NaN
# 2                                       5.3          NaN
# 3                                       8.1          NaN
# 4                                       4.8          NaN
#
# [5 rows x 30 columns]

# %%
df = ec_ac_table.copy()

# Drop unnamed column
df.drop("Unnamed: 29", axis=1, inplace=True)

# Melt to long format
id_cols = ["Code", "Name"]
long = df.melt(
    id_vars=id_cols, 
    var_name="measure",
    value_name="count"
)
# long

# Split measure into parts
parts = long["measure"].str.split(";", expand=True)
# long["type"] = parts[0].str.strip()
long["sex"] = parts[1].str.strip()
long["variable"] = parts[2].str.strip()
long["year"] = pd.to_numeric(parts[3]).astype("Int64")

# Re pivot
long = long.pivot(
    columns="variable",
    index=["Code", "Name", "sex", "year"],
    values="count"
).reset_index()

out = long.rename(
        columns={"Code": "code", "Name": "powiat"}
    )

# out

out.to_csv(repo_root / "cleaned/03_01_outcome_data/nc_activity_table.csv")

# %% [markdown]
# **E - Voivodeship Rates**
#
# Cleaning p4108 - activity rate, and p4113 - employment rate

# %%
p4108 = pd.read_csv(repo_root / "raw/03_01_population_data/03_01_lfs_vo_activity_rate_p4108.csv", delimiter=";")
p4108.head()
# Out:
#       Code                Name  total;total;numerical data;2010;[%]  \
# 0   200000        DOLNOŚLĄSKIE                                 53.9
# 1   400000  KUJAWSKO-POMORSKIE                                 53.8
# 2   600000           LUBELSKIE                                 52.9
# 3   800000            LUBUSKIE                                 55.2
# 4  1000000             ŁÓDZKIE                                 54.6
#
#    total;total;numerical data;2011;[%]  total;total;numerical data;2012;[%]  \
# 0                                 53.3                                 53.8
# 1                                 53.7                                 55.7
# 2                                 53.8                                 54.1
# 3                                 54.5                                 53.3
# 4                                 55.4                                 55.2
#
#    total;total;numerical data;2013;[%]  total;total;numerical data;2014;[%]  \
# 0                                 54.0                                 55.2
# 1                                 55.3                                 54.9
# 2                                 53.9                                 54.5
# 3                                 54.0                                 53.7
# 4                                 56.2                                 57.0
#
#    total;total;numerical data;2015;[%]  total;total;numerical data;2016;[%]  \
# 0                                 55.5                                 56.8
# 1                                 55.1                                 55.4
# 2                                 54.7                                 53.8
# 3                                 54.5                                 55.7
# 4                                 56.2                                 56.1
#
#    total;total;numerical data;2017;[%]  ...  \
# 0                                 56.4  ...
# 1                                 54.9  ...
# 2                                 53.9  ...
# 3                                 55.7  ...
# 4                                 57.2  ...
#
#    50-89;total;numerical data;2016;[%]  50-89;total;numerical data;2017;[%]  \
# 0                                 34.3                                 33.9
# 1                                 33.4                                 33.2
# 2                                 32.8                                 33.1
# 3                                 35.2                                 34.4
# 4                                 33.5                                 34.7
#
#    50-89;total;numerical data;2018;[%]  50-89;total;numerical data;2019;[%]  \
# 0                                 33.6                                 33.6
# 1                                 33.5                                 32.8
# 2                                 33.0                                 32.6
# 3                                 34.0                                 33.6
# 4                                 34.5                                 32.3
#
#    50-89;total;numerical data;2020;[%]  50-89;total;numerical data;2021;[%]  \
# 0                                 33.7                                 35.2
# 1                                 32.7                                 36.1
# 2                                 34.0                                 35.7
# 3                                 33.9                                 33.8
# 4                                 33.4                                 35.5
#
#    50-89;total;numerical data;2022;[%]  50-89;total;numerical data;2023;[%]  \
# 0                                 35.7                                 36.3
# 1                                 36.9                                 37.3
# 2                                 36.7                                 35.2
# 3                                 35.9                                 37.3
# 4                                 37.1                                 35.9
#
#    50-89;total;numerical data;2024;[%]  Unnamed: 122
# 0                                 35.1           NaN
# 1                                 37.8           NaN
# 2                                 35.9           NaN
# 3                                 36.4           NaN
# 4                                 36.7           NaN
#
# [5 rows x 123 columns]

# %%
df = p4108.copy()

# Drop unnamed column
df.drop("Unnamed: 122", axis=1, inplace=True)

# Melt to long format
id_cols = ["Code", "Name"]
long = df.melt(
    id_vars=id_cols, 
    var_name="measure",
    value_name="rate"
)
# long

# Split measure into parts
parts = long["measure"].str.split(";", expand=True)
long["age"] = parts[0].str.strip()
# long["residence"] = parts[1].str.strip()
# long["measure"] = parts[2].str.strip()
long["year"] = pd.to_numeric(parts[3]).astype("Int64")
# long

out = long.rename(
        columns={"Code": "code", "Name": "voivodeship"}
    ).loc[:, ["code", "voivodeship", "year", "age", "rate"]]

out.to_csv(repo_root / "cleaned/03_01_outcome_data/lfs_vo_activity_rate_p4108.csv")

out
# Out:
#          code          voivodeship  year    age  rate
# 0      200000         DOLNOŚLĄSKIE  2010  total  53.9
# 1      400000   KUJAWSKO-POMORSKIE  2010  total  53.8
# 2      600000            LUBELSKIE  2010  total  52.9
# 3      800000             LUBUSKIE  2010  total  55.2
# 4     1000000              ŁÓDZKIE  2010  total  54.6
# ...       ...                  ...   ...    ...   ...
# 1915  2400000              ŚLĄSKIE  2024  50-89  33.1
# 1916  2600000       ŚWIĘTOKRZYSKIE  2024  50-89  35.7
# 1917  2800000  WARMIŃSKO-MAZURSKIE  2024  50-89  36.0
# 1918  3000000        WIELKOPOLSKIE  2024  50-89  37.5
# 1919  3200000   ZACHODNIOPOMORSKIE  2024  50-89  35.2
#
# [1920 rows x 5 columns]

# %%
p4113 = pd.read_csv(repo_root / "raw/03_01_population_data/03_01_lfs_vo_employ_rate_p4113.csv", delimiter=";")
p4113.head()
# Out:
#       Code                Name  total;total;numerical data;2010;[%]  \
# 0   200000        DOLNOŚLĄSKIE                                  NaN
# 1   400000  KUJAWSKO-POMORSKIE                                  NaN
# 2   600000           LUBELSKIE                                  NaN
# 3   800000            LUBUSKIE                                  NaN
# 4  1000000             ŁÓDZKIE                                  NaN
#
#    total;total;numerical data;2011;[%]  total;total;numerical data;2012;[%]  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#    total;total;numerical data;2013;[%]  total;total;numerical data;2014;[%]  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#    total;total;numerical data;2015;[%]  total;total;numerical data;2016;[%]  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#    total;total;numerical data;2017;[%]  ...  \
# 0                                  NaN  ...
# 1                                  NaN  ...
# 2                                  NaN  ...
# 3                                  NaN  ...
# 4                                  NaN  ...
#
#    60-89;total;numerical data;2016;[%]  60-89;total;numerical data;2017;[%]  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#    60-89;total;numerical data;2018;[%]  60-89;total;numerical data;2019;[%]  \
# 0                                  NaN                                 15.5
# 1                                  NaN                                 13.1
# 2                                  NaN                                 11.9
# 3                                  NaN                                 15.0
# 4                                  NaN                                 12.5
#
#    60-89;total;numerical data;2020;[%]  60-89;total;numerical data;2021;[%]  \
# 0                                 16.4                                 17.5
# 1                                 13.4                                 15.0
# 2                                 12.4                                 15.3
# 3                                 15.3                                 15.3
# 4                                 13.5                                 14.9
#
#    60-89;total;numerical data;2022;[%]  60-89;total;numerical data;2023;[%]  \
# 0                                 17.5                                 17.2
# 1                                 14.7                                 14.0
# 2                                 14.9                                 14.6
# 3                                 16.4                                 17.0
# 4                                 17.1                                 14.8
#
#    60-89;total;numerical data;2024;[%]  Unnamed: 197
# 0                                 14.5           NaN
# 1                                 14.2           NaN
# 2                                 14.5           NaN
# 3                                 16.3           NaN
# 4                                 15.8           NaN
#
# [5 rows x 198 columns]

# %%
df = p4113.copy()

# Drop unnamed column
df.drop("Unnamed: 197", axis=1, inplace=True)

# Melt to long format
id_cols = ["Code", "Name"]
long = df.melt(
    id_vars=id_cols, 
    var_name="measure",
    value_name="rate"
)

# Split measure into parts
parts = long["measure"].str.split(";", expand=True)
long["age"] = parts[0].str.strip()
# long["residence"] = parts[1].str.strip()
# long["measure"] = parts[2].str.strip()
long["year"] = pd.to_numeric(parts[3]).astype("Int64")
long

out = long.rename(
        columns={"Code": "code", "Name": "voivodeship"}
    ).loc[:, ["code", "voivodeship", "year", "age", "rate"]]

out.to_csv(repo_root / "cleaned/03_01_outcome_data/lfs_vo_employ_rate_p4113.csv")

out
# Out:
#          code          voivodeship  year    age  rate
# 0      200000         DOLNOŚLĄSKIE  2010  total   NaN
# 1      400000   KUJAWSKO-POMORSKIE  2010  total   NaN
# 2      600000            LUBELSKIE  2010  total   NaN
# 3      800000             LUBUSKIE  2010  total   NaN
# 4     1000000              ŁÓDZKIE  2010  total   NaN
# ...       ...                  ...   ...    ...   ...
# 3115  2400000              ŚLĄSKIE  2024  60-89  12.4
# 3116  2600000       ŚWIĘTOKRZYSKIE  2024  60-89  12.6
# 3117  2800000  WARMIŃSKO-MAZURSKIE  2024  60-89  14.8
# 3118  3000000        WIELKOPOLSKIE  2024  60-89  14.5
# 3119  3200000   ZACHODNIOPOMORSKIE  2024  60-89  15.0
#
# [3120 rows x 5 columns]
